# %%
import cv2
print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.8.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("img.jpg")

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img);

# %%
print(type(img))
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (4000, 6000, 3)

# %%
R, G, B = img[1968][2968]
print("Red channel  :", R)
print("Green channel:", G)
print("Blue channel :", B)
# Out:
# Red channel  : 122
# Green channel: 126
# Blue channel : 93

# %%
cropped_img = img[1790:2469, 2610:3309]
plt.imshow(cropped_img);

# %%
# !wget "https://courses.openedu.ru/assets/courseware/v1/c2a36c73b1abba800a8ce6c58cb3e689/asset-v1:ITMOUniversity+IMAGPROC+fall_2023_ITMO_bac+type@asset+block/michael-sturgeon-Qjragw8c4b4-unsplash.jpg"
# Out:
# --2023-09-23 15:54:06--  https://courses.openedu.ru/assets/courseware/v1/c2a36c73b1abba800a8ce6c58cb3e689/asset-v1:ITMOUniversity+IMAGPROC+fall_2023_ITMO_bac+type@asset+block/michael-sturgeon-Qjragw8c4b4-unsplash.jpg
# Resolving courses.openedu.ru (courses.openedu.ru)... 178.248.235.109
# Connecting to courses.openedu.ru (courses.openedu.ru)|178.248.235.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1120139 (1.1M) [image/jpeg]
# Saving to: ‘michael-sturgeon-Qjragw8c4b4-unsplash.jpg.1’
#
# michael-sturgeon-Qj 100%[===================>]   1.07M  1.47MB/s    in 0.7s
#
# 2023-09-23 15:54:08 (1.47 MB/s) - ‘michael-sturgeon-Qjragw8c4b4-unsplash.jpg.1’ saved [1120139/1120139]

# %%
img_name = "michael-sturgeon-Qjragw8c4b4-unsplash.jpg"

# %%
img = cv2.imread(img_name)

# %%
h, w, c = img.shape
new_width = 600

k = w / h
dim = (new_width, int(new_width / k))

resized_img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

# %%
print("Coeff: ", k)
# Out:
# Coeff:  1.5

# %%
print("Height: ", resized_img.shape[0])
# Out:
# Height:  400

# %%
cv2.imwrite("final_img.jpg", resized_img)
# Out:
# True

# %%
import os
print(os.stat("final_img.jpg").st_size)
# Out:
# 46133
